# %%
from astropy.coordinates.angle_utilities import angular_separation
from astropy.coordinates import SkyCoord, get_sun,FK4
from astropy.time import Time

from datetime import timedelta
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import os
import glob
import numpy as np
import astropy.units as u

from collections import Counter

# %%
def bandToFreq(band):
    # Convert the input to a numpy array (if it's not already)
    band = np.asarray(band)
    
    # Create a mapping of band numbers to frequency values
    band_to_freq = {
        1: 0.45, 2: 0.70, 3: 0.90, 4: 1.31,
        5: 2.20, 6: 3.93, 7: 4.70, 8: 6.55, 9: 9.18
    }

    # Use np.vectorize to apply the mapping to each element in the array
    freq = np.vectorize(lambda b: band_to_freq.get(b, -1))(band)
    
    return freq

# %%
def sigmaClip(y, N):
    y = np.asarray(y)
    overall_mask = np.ones(len(y), dtype=bool)  # Initialize overall mask to all True
    
    for _ in range(N):
        median = np.median(y[overall_mask])  # Calculate median only on filtered values
        std_dev = np.std(y[overall_mask])    # Calculate std_dev only on filtered values
        
        # Mask values within 1 sigma of the mean
        current_mask = (y >= median - std_dev) & (y <= median + std_dev)
        overall_mask &= current_mask  # Update overall mask with new filtering
    
    return overall_mask

# %%
# Load the file to inspect its contents
filename = r"C:\Users\adamf\Documents\PhD\Diffraction\interpolatedRAE2MasterFile.csv"

rawData = pd.read_csv(filename)
data = rawData
data['time'] = pd.to_datetime(data['time'])
data.drop('Unnamed: 0',axis=1,inplace=True)
data.set_index('time',inplace=True)

# %%
data.iloc[-100000]
# Out:
# frequency_band         6.000000e+00
# position_x            -6.983776e+02
# position_y             2.938816e+02
# position_z             2.666922e+03
# earth_unit_vector_x    6.585006e-01
# earth_unit_vector_y    6.826953e-01
# earth_unit_vector_z    3.167080e-01
# right_ascension        8.294251e+00
# declination            7.935045e+01
# rv1_coarse             7.116068e+05
# rv2_coarse             1.226222e+06
# rv1_fine               1.644602e+06
# rv2_fine               1.261825e+06
# rv_temp                1.092427e+09
# Name: 1975-06-20 11:46:15.040000, dtype: float64

# %%
start_date = pd.to_datetime("1974-01-01 00:00")
end_date = pd.to_datetime("1975-06-30 23:00")

# Selecting rows within the date range
earthOccult = data[(data.index >= start_date) & (data.index <= end_date)].copy()

# %%
earthOccult.head(50)
# Out:
#                          frequency_band   position_x  position_y   position_z  \
# time
# 1974-01-01 00:00:16.633               5 -2342.408478    0.726133  1525.056671
# 1974-01-01 00:00:18.558               5 -2341.700745   -1.483316  1526.104797
# 1974-01-01 00:00:20.483               5 -2340.993011   -3.692764  1527.152924
# 1974-01-01 00:00:22.408               5 -2340.285278   -5.902213  1528.201050
# 1974-01-01 00:00:24.333               5 -2339.577545   -8.111661  1529.249176
# 1974-01-01 00:00:26.258               5 -2338.869812  -10.321110  1530.297302
# 1974-01-01 00:00:28.183               5 -2338.162079  -12.530558  1531.345428
# 1974-01-01 00:00:31.992               4 -2336.746521  -16.949742  1533.441772
# 1974-01-01 00:00:33.917               4 -2336.038696  -19.159478  1534.489990
# 1974-01-01 00:00:35.842               4 -2335.330872  -21.369214  1535.538208
# 1974-01-01 00:00:37.767               4 -2334.623047  -23.578949  1536.586426
# 1974-01-01 00:01:35.356  0.000000e+00  1092637163
# 1974-01-01 00:01:37.281  0.000000e+00  1092637163
# 1974-01-01 00:01:39.206  4.385308e+05  1092637163
# 1974-01-01 00:01:41.131  0.000000e+00  1092637163
# 1974-01-01 00:01:43.056  0.000000e+00  1092637163
# 1974-01-01 00:01:44.981  0.000000e+00  1092637163
# 1974-01-01 00:01:48.790  0.000000e+00  1092637163
# 1974-01-01 00:01:50.715  0.000000e+00  1092637163
# 1974-01-01 00:01:52.640  0.000000e+00  1092637163
# 1974-01-01 00:01:54.565  5.055059e+05  1092637163
# 1974-01-01 00:01:56.490  0.000000e+00  1092637163
# 1974-01-01 00:01:58.415  0.000000e+00  1092637163
# 1974-01-01 00:02:00.340  0.000000e+00  1092637163
# 1974-01-01 00:02:04.150  0.000000e+00  1092637163
# 1974-01-01 00:02:06.075  0.000000e+00  1092637163

# %%
frequencies = np.sort(earthOccult['frequency_band'].unique())

# %%
earthOccult['TimeSince'] = (earthOccult.index-earthOccult.index[0]).total_seconds()

# %%
# %matplotlib qt
fig, axes = plt.subplots(3, 3, figsize=(9, 5 * len(frequencies)), sharex=True)
for ax, freq in zip(axes.flatten(), frequencies):
    subset = earthOccult[earthOccult['frequency_band']==freq]
    x = subset['TimeSince']
    
    
    
    mask = sigmaClip(subset['rv1_coarse'],2)
    ax.scatter(x,subset['rv1_coarse'])
    #ax.scatter(x,clip,color = 'green')
    
    ax.set_title(f'Frequency: {bandToFreq(freq)}MHz')
    ax.set_xlabel('Time since start of period (s)')
    ax.set_ylabel('rv1_coarse')
    ax.grid(True)

# %%
#If a burst occurs in 3 frequency bins, accept it and record it as an event
#run sigma clips on smaller samples and then look at if dots are significantly above
#assign z-score to specific points
#evaluate if there are multiple points above a threshold near each other (all same frequency)
#determine a background variation in the smooth area, and then see if consecutive points are 5 background variation above
#give everything a burst probability score

# %%
#check for 7 points in a row above baseline by at least 5 background variations above, in 3 bins within a 30 min window.

# %%
def combine_overlapping_windows(windows):
    """
    Combine overlapping or adjacent windows into a single window.

    Parameters:
        windows (list of tuples): List of (start_idx, end_idx) windows.

    Returns:
        list of tuples: Combined windows.
    """
    if not windows:
        return []

    # Sort windows by their start index
    windows = sorted(windows, key=lambda x: x[0])

    # Initialize with the first window
    combined_windows = [windows[0]]

    for start, end in windows[1:]:
        last_start, last_end = combined_windows[-1]

        # Check for overlap or adjacency
        if start <= last_end:  # Overlapping or adjacent windows
            # Merge windows
            combined_windows[-1] = (last_start, max(last_end, end))
        else:
            # No overlap, add as a new window
            combined_windows.append((start, end))

    return combined_windows

# %%
def burstWindows(data, window_time=10, consec_points=7):
    """
    Detect burst windows in the data and return their start and end times as datetime objects.

    Parameters:
        data (pd.DataFrame): The input data with a datetime index.
        window_time (int): Size of the sliding window (in indices).
        consec_points (int): Number of consecutive points exceeding the threshold.

    Returns:
        list of tuples: Start and end times of valid windows as datetime objects.
    """
    freqs = data['frequency_band'].unique()
    freq_indices = {}

    # Detect bursts for each frequency band
    for freq in freqs:
        freq_df = data[data['frequency_band'] == freq]
        background_points = sigmaClip(freq_df['rv1_coarse'], 3)
        med = np.median(freq_df['rv1_coarse'][background_points])
        std = np.std(freq_df['rv1_coarse'][background_points])
        z = (freq_df['rv1_coarse'] - med) / std
        cond = z > 10
        consecutive_points = np.convolve(cond, np.ones(consec_points, dtype=int), mode='valid')
        indices = np.where(consecutive_points == consec_points)[0]
        freq_indices[freq] = indices
        
    # Initialize a list for windows meeting the condition
    valid_windows = []
    # Check for overlap in windows
    max_index = len(data)
    for start_idx in range(max_index - window_time + 1):
        end_idx = start_idx + window_time
        count = 0

        for freq, indices in freq_indices.items():
            # Check if any indices fall within the current window
            in_window = (indices >= start_idx) & (indices < end_idx)
            if np.any(in_window):
                count += 1
            if count >= 3:
                # Store the start and end indices of the window
                valid_windows.append((start_idx, end_idx))
                break
    # Combine overlapping windows
    valid_windows = combine_overlapping_windows(valid_windows)
    # Refine the window times using all frequency bands
    datetime_windows = []
    for start_idx, end_idx in valid_windows:
        # Initialize variables to track the earliest start time and latest end time
        earliest_time = data.index[-1]
        latest_time = data.index[0]
        # Check across all frequency bands to find the earliest start and latest end
        for freq in freqs:
            freq_df = data[data['frequency_band'] == freq]
            try:#this is because sometimes the freq_df are shorter than others, due to gaps in the data
                early_time = freq_df.index[start_idx]
            
                if(early_time<earliest_time):
                    earliest_time = early_time
                late_time = freq_df.index[end_idx]
                if(late_time>latest_time):
                    latest_time = late_time
            except:
                continue
        # Append the refined window times
        if earliest_time and latest_time:
            datetime_windows.append((earliest_time, latest_time))

    return datetime_windows

# %%
def burst_detection_chunks(data, window_time=10, consec_points=7, chunk_size='24h'):
    """
    Apply the burstWindows function on chunks of the data and combine overlapping windows.

    Parameters:
        data (pd.DataFrame): The input DataFrame, indexed by datetime objects.
        time_col (str): Name of the column containing datetime objects.
        window_time (int): The size of the sliding window (in indices).
        consec_points (int): Number of consecutive points exceeding the threshold.
        chunk_size (str): The size of each chunk (e.g., 'H' for hourly chunks).

    Returns:
        dict: A dictionary where keys are the start time of each burst (datetime) and values are
              the corresponding (start_time, end_time) for each burst.
    """
    # Ensure the index is sorted by datetime
    data = data.sort_index()

    # Split data into chunks based on chunk_size
    chunks = [
        (start, chunk)
        for start, chunk in data.groupby(pd.Grouper(freq=chunk_size))
    ]
    burst_results = []

    for _, chunk in chunks:
        if not chunk.empty:
            # Apply burstWindows to the current chunk
            valid_windows = burstWindows(chunk, window_time=window_time, consec_points=consec_points)

            
            # Convert indices to datetime values
            for start_time, end_time in valid_windows:
                # Store in the results with the start time of the burst as the key
                burst_results.append(np.array([start_time, end_time]))
    
    return burst_results

# %%
bursts = burst_detection_chunks(earthOccult)

# %%
print(bursts)
# Out:
# [array([Timestamp('1974-01-01 06:19:06.684000'),
#        Timestamp('1974-01-01 06:55:02.754000')], dtype=object), array([Timestamp('1974-01-01 08:56:48.160000'),
#        Timestamp('1974-01-01 13:13:32.736000')], dtype=object), array([Timestamp('1974-01-01 17:27:00.630000'),
#        Timestamp('1974-01-01 18:31:15.864000')], dtype=object), array([Timestamp('1974-01-01 19:20:40.248000'),
#        Timestamp('1974-01-07 23:16:57.412000')], dtype=object), array([Timestamp('1974-01-08 04:37:56.512000'),
#        Timestamp('1974-01-08 05:01:12.331000')], dtype=object), array([Timestamp('1974-01-08 04:55:17.130000'),
#        Timestamp('1974-01-08 05:35:55.491000')], dtype=object), array([Timestamp('1974-01-08 06:41:04.585000'),
#        Timestamp('1974-01-08 07:07:34.307000')], dtype=object), array([Timestamp('1974-01-08 07:28:41.512000'),
#        Timestamp('1974-01-08 07:51:41.971000')], dtype=object), array([Timestamp('1974-01-08 08:45:12.173000'),
#        Timestamp('1974-01-08 09:23:15.011000')], dtype=object), array([Timestamp('1974-01-08 12:00:16.356000'),
#        Timestamp('1974-01-08 13:26:47.730000')], dtype=object), array([Timestamp('1974-01-08 12:14:01.936000'),
#        Timestamp('1974-01-08 13:39:29.905000')], dtype=object), array([Timestamp('1974-01-08 14:42:28.219000'),
#        Timestamp('1974-01-08 15:55:12.100000')], dtype=object), array([Timestamp('1974-01-08 15:33:24.660000'),
#        Timestamp('1974-01-08 18:00:24.682000')], dtype=object), array([Timestamp('1974-01-08 15:53:07.303000'),
#        Timestamp('1974-01-08 18:09:43.410000')], dtype=object), array([Timestamp('1974-01-08 16:03:37.022000'),
#        Timestamp('1974-01-08 18:32:55.377000')], dtype=object), array([Timestamp('1974-01-08 17:20:15.118000'),
#        Timestamp('1974-01-08 18:44:20.793000')], dtype=object), array([Timestamp('1974-01-08 17:31:48.234000'),
#        Timestamp('1974-01-08 18:54:56.319000')], dtype=object), array([Timestamp('1974-01-08 18:34:31.385000'),
#        Timestamp('1974-01-08 19:21:12.604000')], dtype=object), array([Timestamp('1974-01-08 18:41:26.100000'),
#        Timestamp('1974-01-08 19:26:00.630000')], dtype=object), array([Timestamp('1974-01-08 19:01:04.955000'),
#        Timestamp('1974-01-08 19:44:11.176000')], dtype=object), array([Timestamp('1974-01-09 06:39:47.452000'),
#        Timestamp('1974-01-09 08:58:28.626000')], dtype=object), array([Timestamp('1974-01-09 12:22:53.246000'),
#        Timestamp('1974-01-09 14:31:08.406000')], dtype=object), array([Timestamp('1974-01-09 13:49:17.131000'),
#        Timestamp('1974-01-09 16:05:11.211000')], dtype=object), array([Timestamp('1974-01-09 17:37:49.497000'),
#        Timestamp('1974-01-09 20:28:17.132000')], dtype=object), array([Timestamp('1974-01-09 18:59:06.222000'),
#        Timestamp('1974-01-09 21:20:30.511000')], dtype=object), array([Timestamp('1974-01-09 19:27:58.018000'),
#        Timestamp('1974-01-09 21:53:06.968000')], dtype=object), array([Timestamp('1974-01-09 21:26:12.275000'),
#        Timestamp('1974-01-09 22:02:37.202000')], dtype=object), array([Timestamp('1974-01-10 08:02:57.112000'),
#        Timestamp('1974-01-10 08:22:12.896000')], dtype=object), array([Timestamp('1974-01-10 08:20:10.019000'),
#        Timestamp('1974-01-10 09:08:38.535000')], dtype=object), array([Timestamp('1974-01-10 11:44:19.340000'),
#        Timestamp('1974-01-10 12:24:02.065000')], dtype=object), array([Timestamp('1974-01-10 12:08:34.690000'),
#        Timestamp('1974-01-10 13:03:19.584000')], dtype=object), array([Timestamp('1974-01-10 16:17:01.369000'),
#        Timestamp('1974-01-10 17:22:12.317000')], dtype=object), array([Timestamp('1974-01-10 19:22:12.166000'),
#        Timestamp('1974-01-10 20:21:56.751000')], dtype=object), array([Timestamp('1974-01-11 02:20:24.108000'),
#        Timestamp('1974-01-11 03:08:54.739000')], dtype=object), array([Timestamp('1974-01-11 03:08:20.170000'),
#        Timestamp('1974-01-11 03:50:42.210000')], dtype=object), array([Timestamp('1974-01-11 03:39:45.596000'),
#        Timestamp('1974-01-11 04:12:39.290000')], dtype=object), array([Timestamp('1974-01-12 00:00:06.382000'),
#        Timestamp('1974-01-12 02:00:02.533000')], dtype=object), array([Timestamp('1974-01-12 01:59:10.678000'),
#        Timestamp('1974-01-12 02:10:32.288000')], dtype=object), array([Timestamp('1974-01-12 06:49:03.837000'),
#        Timestamp('1974-01-12 07:31:52.787000')], dtype=object), array([Timestamp('1974-01-12 20:43:30.001000'),
#        Timestamp('1974-01-12 22:11:12.684000')], dtype=object), array([Timestamp('1974-01-12 20:49:29.052000'),
#        Timestamp('1974-01-12 22:26:11.214000')], dtype=object), array([Timestamp('1974-01-13 01:25:09.659000'),
#        Timestamp('1974-01-13 01:35:56.693000')], dtype=object), array([Timestamp('1974-01-13 10:28:11.515000'),
#        Timestamp('1974-01-13 11:10:06.543000')], dtype=object), array([Timestamp('1974-01-13 15:40:58.998000'),
#        Timestamp('1974-01-13 17:50:19.517000')], dtype=object), array([Timestamp('1974-01-13 16:55:32.533000'),
#        Timestamp('1974-01-13 18:04:07.018000')], dtype=object), array([Timestamp('1974-01-14 22:05:54.285000'),
#        Timestamp('1974-01-14 22:10:21.173000')], dtype=object), array([Timestamp('1974-01-15 03:32:43.010000'),
#        Timestamp('1974-01-15 04:25:34.796000')], dtype=object), array([Timestamp('1974-01-15 07:51:25.888000'),
#        Timestamp('1974-01-15 09:25:55.527000')], dtype=object), array([Timestamp('1974-01-15 10:08:32.890000'),
#        Timestamp('1974-01-15 12:03:40.637000')], dtype=object), array([Timestamp('1974-01-15 10:41:13.192000'),
#        Timestamp('1974-01-15 12:16:28.622000')], dtype=object), array([Timestamp('1974-01-15 10:54:01.175000'),
#        Timestamp('1974-01-15 12:25:41.571000')], dtype=object), array([Timestamp('1974-01-15 11:03:14.123000'),
#        Timestamp('1974-01-15 12:38:29.556000')], dtype=object), array([Timestamp('1974-01-15 14:07:28.957000'),
#        Timestamp('1974-01-15 20:45:35.202000')], dtype=object), array([Timestamp('1974-01-15 21:17:48.607000'),
#        Timestamp('1974-01-15 21:47:13.054000')], dtype=object), array([Timestamp('1974-01-16 04:53:42.337000'),
#        Timestamp('1974-01-16 05:57:28.886000')], dtype=object), array([Timestamp('1974-01-16 05:46:01.554000'),
#        Timestamp('1974-01-16 06:50:37.908000')], dtype=object), array([Timestamp('1974-01-16 06:29:57.631000'),
#        Timestamp('1974-01-16 07:58:01.333000')], dtype=object), array([Timestamp('1974-01-16 12:05:09.255000'),
#        Timestamp('1974-01-16 18:30:48.536000')], dtype=object), array([Timestamp('1974-01-16 19:16:09.128000'),
#        Timestamp('1974-01-16 21:54:56.006000')], dtype=object), array([Timestamp('1974-01-16 19:35:53.750000'),
#        Timestamp('1974-01-16 22:25:08.450000')], dtype=object), array([Timestamp('1974-01-16 20:23:44.103000'),
#        Timestamp('1974-01-16 22:51:42.009000')], dtype=object), array([Timestamp('1974-01-16 23:21:08.375000'),
#        Timestamp('1974-01-16 23:54:00.202000')], dtype=object), array([Timestamp('1974-01-17 00:15:30.555000'),
#        Timestamp('1974-01-17 00:32:33.741000')], dtype=object), array([Timestamp('1974-01-17 03:04:29.743000'),
#        Timestamp('1974-01-17 04:04:45.008000')], dtype=object), array([Timestamp('1974-01-17 03:33:25.390000'),
#        Timestamp('1974-01-17 04:29:13.804000')], dtype=object), array([Timestamp('1974-01-17 06:50:16.999000'),
#        Timestamp('1974-01-17 08:28:00.554000')], dtype=object), array([Timestamp('1974-01-17 10:14:32.114000'),
#        Timestamp('1974-01-17 22:35:45.999000')], dtype=object), array([Timestamp('1974-01-17 10:31:46.949000'),
#        Timestamp('1974-01-17 22:48:33.985000')], dtype=object), array([Timestamp('1974-01-17 10:36:34.974000'),
#        Timestamp('1974-01-17 22:53:18.160000')], dtype=object), array([Timestamp('1974-01-17 10:45:38.298000'),
#        Timestamp('1974-01-17 23:06:04.221000')], dtype=object), array([Timestamp('1974-01-17 21:24:59.057000'),
#        Timestamp('1974-01-17 23:18:46.432000')], dtype=object), array([Timestamp('1974-01-18 01:59:55.366000'),
#        Timestamp('1974-01-18 02:25:25.567000')], dtype=object), array([Timestamp('1974-01-18 09:50:57.001000'),
#        Timestamp('1974-01-18 11:32:42.446000')], dtype=object), array([Timestamp('1974-01-18 16:06:41.132000'),
#        Timestamp('1974-01-18 18:32:09.292000')], dtype=object), array([Timestamp('1974-01-18 16:39:46.383000'),
#        Timestamp('1974-01-18 18:49:31.826000')], dtype=object), array([Timestamp('1974-01-19 10:21:53.704000'),
#        Timestamp('1974-01-19 20:37:10.674000')], dtype=object), array([Timestamp('1974-01-19 20:35:57.726000'),
#        Timestamp('1974-01-19 22:50:36.551000')], dtype=object), array([Timestamp('1974-01-20 00:15:47.494000'),
#        Timestamp('1974-01-20 00:23:43.646000')], dtype=object), array([Timestamp('1974-01-20 01:11:55.127000'),
#        Timestamp('1974-01-20 02:40:14.282000')], dtype=object), array([Timestamp('1974-01-20 12:18:18.297000'),
#        Timestamp('1974-01-20 18:25:58.730000')], dtype=object), array([Timestamp('1974-01-20 18:46:56.304000'),
#        Timestamp('1974-01-20 22:04:58.947000')], dtype=object), array([Timestamp('1974-01-20 18:53:43.317000'),
#        Timestamp('1974-01-20 22:22:27.257000')], dtype=object), array([Timestamp('1974-01-20 23:42:34.843000'),
#        Timestamp('1974-01-20 23:52:37.721000')], dtype=object), array([Timestamp('1974-01-21 00:00:05.013000'),
#        Timestamp('1974-01-21 00:18:21.366000')], dtype=object), array([Timestamp('1974-01-21 03:13:46.597000'),
#        Timestamp('1974-01-21 04:19:30.203000')], dtype=object), array([Timestamp('1974-01-21 03:44:58.576000'),
#        Timestamp('1974-01-21 04:28:47')], dtype=object), array([Timestamp('1974-01-21 05:17:36.841000'),
#        Timestamp('1974-01-21 06:13:13.733000')], dtype=object), array([Timestamp('1974-01-21 05:30:30.598000'),
#        Timestamp('1974-01-21 06:35:08.887000')], dtype=object), array([Timestamp('1974-01-21 06:06:11.323000'),
#        Timestamp('1974-01-21 07:36:44.826000')], dtype=object), array([Timestamp('1974-01-21 06:58:26.614000'),
#        Timestamp('1974-01-21 08:53:11.583000')], dtype=object), array([Timestamp('1974-01-23 03:25:48.439000'),
#        Timestamp('1974-01-23 03:54:13.359000')], dtype=object), array([Timestamp('1974-01-23 06:57:59.656000'),
#        Timestamp('1974-01-23 07:42:30.308000')], dtype=object), array([Timestamp('1974-01-27 17:08:57.909000'),
#        Timestamp('1974-01-27 17:48:06.030000')], dtype=object), array([Timestamp('1974-01-27 17:43:41.064000'),
#        Timestamp('1974-01-27 18:30:20.394000')], dtype=object), array([Timestamp('1974-01-28 15:01:40.863000'),
#        Timestamp('1974-01-28 15:15:36.025000')], dtype=object), array([Timestamp('1974-01-28 15:30:38.441000'),
#        Timestamp('1974-01-28 15:49:54.233000')], dtype=object), array([Timestamp('1974-01-29 15:39:29.708000'),
#        Timestamp('1974-01-29 16:17:21.028000')], dtype=object), array([Timestamp('1974-01-30 09:15:47.216000'),
#        Timestamp('1974-01-30 10:16:42.844000')], dtype=object), array([Timestamp('1974-01-30 09:43:31.807000'),
#        Timestamp('1974-01-30 10:28:14.034000')], dtype=object), array([Timestamp('1974-01-30 12:01:36.504000'),
#        Timestamp('1974-01-30 13:25:30.662000')], dtype=object), array([Timestamp('1974-01-30 12:52:31.175000'),
#        Timestamp('1974-01-30 14:26:53.159000')], dtype=object), array([Timestamp('1974-01-31 04:29:02.411000'),
#        Timestamp('1974-01-31 04:36:50.864000')], dtype=object), array([Timestamp('1974-01-31 05:37:33.057000'),
#        Timestamp('1974-01-31 06:12:00.853000')], dtype=object), array([Timestamp('1974-01-31 07:19:47.384000'),
#        Timestamp('1974-01-31 08:34:42.025000')], dtype=object), array([Timestamp('1974-01-31 11:11:20.285000'),
#        Timestamp('1974-01-31 12:24:15.898000')], dtype=object), array([Timestamp('1974-01-31 11:21:57.736000'),
#        Timestamp('1974-01-31 12:29:00.074000')], dtype=object), array([Timestamp('1974-01-31 13:15:35.554000'),
#        Timestamp('1974-01-31 15:36:55.574000')], dtype=object), array([Timestamp('1974-01-31 13:39:10.578000'),
#        Timestamp('1974-01-31 15:58:50.735000')], dtype=object), array([Timestamp('1974-01-31 14:58:45.545000'),
#        Timestamp('1974-01-31 15:59:32.964000')], dtype=object), array([Timestamp('1974-02-01 02:40:47.131000'),
#        Timestamp('1974-02-01 02:56:47.136000')], dtype=object), array([Timestamp('1974-02-01 03:12:06.796000'),
#        Timestamp('1974-05-04 03:43:09.555000')], dtype=object), array([Timestamp('1974-05-04 03:18:23.589000'),
#        Timestamp('1974-05-04 04:02:54.129000')], dtype=object), array([Timestamp('1974-05-04 06:08:54.646000'),
#        Timestamp('1974-05-04 07:11:51.055000')], dtype=object), array([Timestamp('1974-05-04 06:19:24.368000'),
#        Timestamp('1974-05-04 07:57:09.345000')], dtype=object), array([Timestamp('1974-05-04 06:33:13.759000'),
#        Timestamp('1974-05-04 08:06:16.506000')], dtype=object), array([Timestamp('1974-05-04 09:34:12.460000'),
#        Timestamp('1974-05-04 11:21:04.634000')], dtype=object), array([Timestamp('1974-05-04 13:50:26.923000'),
#        Timestamp('1974-05-04 15:47:54.868000')], dtype=object), array([Timestamp('1974-05-04 16:19:56.680000'),
#        Timestamp('1974-05-04 18:05:55.348000')], dtype=object), array([Timestamp('1974-05-04 16:41:49.863000'),
#        Timestamp('1974-05-04 18:17:26.507000')], dtype=object), array([Timestamp('1974-05-04 18:50:41.245000'),
#        Timestamp('1974-05-04 20:40:03.423000')], dtype=object), array([Timestamp('1974-05-04 18:57:37.866000'),
#        Timestamp('1974-05-04 20:50:25.445000')], dtype=object), array([Timestamp('1974-05-04 19:54:29.506000'),
#        Timestamp('1974-05-04 22:13:58.280000')], dtype=object), array([Timestamp('1974-05-04 20:40:41.800000'),
#        Timestamp('1974-05-04 23:03:55.196000')], dtype=object), array([Timestamp('1974-05-04 21:39:45.897000'),
#        Timestamp('1974-05-04 23:34:45.947000')], dtype=object), array([Timestamp('1974-05-04 21:54:54.008000'),
#        Timestamp('1974-05-04 23:49:52.134000')], dtype=object), array([Timestamp('1974-05-04 22:14:34.732000'),
#        Timestamp('1974-05-04 23:20:08.554000')], dtype=object), array([Timestamp('1974-05-05 00:14:11.711000'),
#        Timestamp('1974-05-05 00:29:15.511000')], dtype=object), array([Timestamp('1974-05-05 00:47:47.141000'),
#        Timestamp('1974-05-05 00:56:10.141000')], dtype=object), array([Timestamp('1974-05-05 01:09:49.948000'),
#        Timestamp('1974-05-05 01:23:48.924000')], dtype=object), array([Timestamp('1974-05-05 03:29:35.990000'),
#        Timestamp('1974-05-05 04:11:02.236000')], dtype=object), array([Timestamp('1974-05-05 05:36:05.300000'),
#        Timestamp('1974-05-05 06:51:03.575000')], dtype=object), array([Timestamp('1974-05-05 07:08:45.275000'),
#        Timestamp('1974-05-05 08:15:45.498000')], dtype=object), array([Timestamp('1974-05-05 08:16:31.576000'),
#        Timestamp('1974-05-05 09:26:20.749000')], dtype=object), array([Timestamp('1974-05-05 09:57:21.090000'),
#        Timestamp('1974-05-05 11:44:17.335000')], dtype=object), array([Timestamp('1974-05-05 10:40:57.909000'),
#        Timestamp('1974-05-05 12:29:35.893000')], dtype=object), array([Timestamp('1974-05-05 14:48:30.165000'),
#        Timestamp('1974-05-05 16:20:22.121000')], dtype=object), array([Timestamp('1974-05-05 15:14:36.783000'),
#        Timestamp('1974-05-05 16:45:58.021000')], dtype=object), array([Timestamp('1974-05-05 15:29:41.039000'),
#        Timestamp('1974-05-05 16:59:47.407000')], dtype=object), array([Timestamp('1974-05-05 17:30:16.969000'),
#        Timestamp('1974-05-05 19:15:27.650000')], dtype=object), array([Timestamp('1974-05-05 17:41:44.280000'),
#        Timestamp('1974-05-05 19:30:29.989000')], dtype=object), array([Timestamp('1974-05-05 18:27:06.698000'),
#        Timestamp('1974-05-05 20:22:39.404000')], dtype=object), array([Timestamp('1974-05-05 19:17:57.391000'),
#        Timestamp('1974-05-05 21:24:09.446000')], dtype=object), array([Timestamp('1974-05-05 19:43:39.080000'),
#        Timestamp('1974-05-05 21:50:41.013000')], dtype=object), array([Timestamp('1974-05-05 20:03:15.959000'),
#        Timestamp('1974-05-05 22:08:05.429000')], dtype=object), array([Timestamp('1974-05-05 20:19:21.660000'),
#        Timestamp('1974-05-05 22:25:37.545000')], dtype=object), array([Timestamp('1974-05-05 20:32:15.392000'),
#        Timestamp('1974-05-05 22:42:54.261000')], dtype=object), array([Timestamp('1974-05-06 00:07:11.667000'),
#        Timestamp('1974-05-06 00:19:30.402000')], dtype=object), array([Timestamp('1974-05-06 05:27:15.887000'),
#        Timestamp('1974-05-06 06:16:17.115000')], dtype=object), array([Timestamp('1974-05-06 07:40:39.851000'),
#        Timestamp('1974-05-06 09:25:17.771000')], dtype=object), array([Timestamp('1974-05-06 10:50:49.649000'),
#        Timestamp('1974-05-06 12:52:50.126000')], dtype=object), array([Timestamp('1974-05-06 11:34:51.421000'),
#        Timestamp('1974-05-06 13:39:12.048000')], dtype=object), array([Timestamp('1974-05-06 14:02:02.858000'),
#        Timestamp('1974-05-06 16:05:20.161000')], dtype=object), array([Timestamp('1974-05-06 14:14:50.813000'),
#        Timestamp('1974-05-06 16:14:33.087000')], dtype=object), array([Timestamp('1974-05-06 15:55:42.292000'),
#        Timestamp('1974-05-06 17:48:29.862000')], dtype=object), array([Timestamp('1974-05-06 17:12:14.651000'),
#        Timestamp('1974-05-06 19:09:36.759000')], dtype=object), array([Timestamp('1974-05-06 17:34:07.830000'),
#        Timestamp('1974-05-06 19:49:07.824000')], dtype=object), array([Timestamp('1974-05-06 18:04:27.899000'),
#        Timestamp('1974-05-06 20:28:31.194000')], dtype=object), array([Timestamp('1974-05-06 18:15:53.282000'),
#        Timestamp('1974-05-06 20:35:22.039000')], dtype=object), array([Timestamp('1974-05-06 18:20:35.520000'),
#        Timestamp('1974-05-06 20:55:10.461000')], dtype=object), array([Timestamp('1974-05-06 18:38:01.861000'),
#        Timestamp('1974-05-06 21:05:34.408000')], dtype=object), array([Timestamp('1974-05-06 19:08:06.530000'),
#        Timestamp('1974-05-06 21:40:30.940000')], dtype=object), array([Timestamp('1974-05-06 21:57:22.713000'),
#        Timestamp('1974-05-06 22:35:44.647000')], dtype=object), array([Timestamp('1974-05-06 22:12:25.047000'),
#        Timestamp('1974-05-06 22:50:46.981000')], dtype=object), array([Timestamp('1974-05-06 22:40:17.260000'),
#        Timestamp('1974-05-06 23:34:54.498000')], dtype=object), array([Timestamp('1974-05-06 23:16:09.435000'),
#        Timestamp('1974-05-06 23:49:01.172000')], dtype=object), array([Timestamp('1974-05-07 01:22:25.311000'),
#        Timestamp('1974-05-07 01:43:53.549000')], dtype=object), array([Timestamp('1974-05-07 01:58:17.507000'),
#        Timestamp('1974-05-07 02:20:58.691000')], dtype=object), array([Timestamp('1974-05-07 02:28:29.879000'),
#        Timestamp('1974-05-07 03:24:46.948000')], dtype=object), array([Timestamp('1974-05-07 02:44:37.501000'),
#        Timestamp('1974-05-07 03:42:09.439000')], dtype=object), array([Timestamp('1974-05-07 03:27:53.182000'),
#        Timestamp('1974-05-07 04:01:55.937000')], dtype=object), array([Timestamp('1974-05-07 05:16:56.142000'),
#        Timestamp('1974-05-07 06:15:10.307000')], dtype=object), array([Timestamp('1974-05-07 05:53:53.580000'),
#        Timestamp('1974-05-07 08:47:05.950000')], dtype=object), array([Timestamp('1974-05-07 08:58:15.971000'),
#        Timestamp('1974-05-07 10:45:19.872000')], dtype=object), array([Timestamp('1974-05-07 09:05:16.439000'),
#        Timestamp('1974-05-07 10:58:11.674000')], dtype=object), array([Timestamp('1974-05-07 09:37:43.182000'),
#        Timestamp('1974-05-07 11:30:40.347000')], dtype=object), array([Timestamp('1974-05-07 12:47:49.152000'),
#        Timestamp('1974-05-07 14:22:03.250000')], dtype=object), array([Timestamp('1974-05-07 13:01:38.540000'),
#        Timestamp('1974-05-07 14:27:56.507000')], dtype=object), array([Timestamp('1974-05-07 13:19:12.580000'),
#        Timestamp('1974-05-07 14:47:43.002000')], dtype=object), array([Timestamp('1974-05-07 13:29:42.300000'),
#        Timestamp('1974-05-07 15:01:30.464000')], dtype=object), array([Timestamp('1974-05-07 14:09:07.640000'),
#        Timestamp('1974-05-07 15:36:19.290000')], dtype=object), array([Timestamp('1974-05-07 14:53:05.541000'),
#        Timestamp('1974-05-07 16:35:32.999000')], dtype=object), array([Timestamp('1974-05-07 15:30:08.749000'),
#        Timestamp('1974-05-07 17:29:56.770000')], dtype=object), array([Timestamp('1974-05-07 16:05:07.201000'),
#        Timestamp('1974-05-07 18:14:02.345000')], dtype=object), array([Timestamp('1974-05-07 16:46:48.796000'),
#        Timestamp('1974-05-07 18:48:51.177000')], dtype=object), array([Timestamp('1974-05-07 16:56:01.721000'),
#        Timestamp('1974-05-07 19:01:37.205000')], dtype=object), array([Timestamp('1974-05-07 17:06:23.740000'),
#        Timestamp('1974-05-07 19:17:42.901000')], dtype=object), array([Timestamp('1974-05-07 17:20:22.752000'),
#        Timestamp('1974-05-07 19:25:52.466000')], dtype=object), array([Timestamp('1974-05-07 17:30:52.472000'),
# ...
#        Timestamp('1975-05-20 15:55:52.699000')], dtype=object), array([Timestamp('1975-05-20 15:32:48.410000'),
#        Timestamp('1975-05-20 19:31:04.284000')], dtype=object), array([Timestamp('1975-05-21 07:29:19.998000'),
#        Timestamp('1975-05-21 08:13:54.490000')], dtype=object), array([Timestamp('1975-05-21 11:14:32.549000'),
#        Timestamp('1975-05-21 11:50:36.350000')], dtype=object), array([Timestamp('1975-05-21 18:35:02.476000'),
#        Timestamp('1975-05-21 18:45:49.505000')], dtype=object), array([Timestamp('1975-05-21 18:50:06.769000'),
#        Timestamp('1975-05-21 18:58:02.917000')], dtype=object), array([Timestamp('1975-05-22 08:16:58.623000'),
#        Timestamp('1975-05-22 08:36:08.649000')], dtype=object), array([Timestamp('1975-05-22 09:45:08.011000'),
#        Timestamp('1975-05-22 10:01:36.743000')], dtype=object), array([Timestamp('1975-05-22 12:19:46.994000'),
#        Timestamp('1975-05-22 12:53:28.691000')], dtype=object), array([Timestamp('1975-05-22 12:54:47.415000'),
#        Timestamp('1975-05-22 13:42:07.023000')], dtype=object), array([Timestamp('1975-05-22 13:41:42.079000'),
#        Timestamp('1975-05-22 14:41:17.025000')], dtype=object), array([Timestamp('1975-05-22 14:04:59.806000'),
#        Timestamp('1975-05-22 14:53:57.307000')], dtype=object), array([Timestamp('1975-05-22 15:45:51.246000'),
#        Timestamp('1975-05-22 15:58:12.304000')], dtype=object), array([Timestamp('1975-05-23 12:15:04.225000'),
#        Timestamp('1975-05-23 12:48:30.576000')], dtype=object), array([Timestamp('1975-05-23 12:59:21.460000'),
#        Timestamp('1975-05-23 19:01:04.773000')], dtype=object), array([Timestamp('1975-05-23 19:16:28.282000'),
#        Timestamp('1975-05-23 21:50:17.414000')], dtype=object), array([Timestamp('1975-05-24 00:28:31.559000'),
#        Timestamp('1975-05-24 00:38:36.318000')], dtype=object), array([Timestamp('1975-05-24 00:39:32.021000'),
#        Timestamp('1975-05-24 00:50:13.274000')], dtype=object), array([Timestamp('1975-05-24 15:05:15.724000'),
#        Timestamp('1975-05-24 15:41:25.320000')], dtype=object), array([Timestamp('1975-05-24 15:34:13.317000'),
#        Timestamp('1975-05-24 19:00:23.544000')], dtype=object), array([Timestamp('1975-05-24 15:51:18.581000'),
#        Timestamp('1975-05-24 19:17:51.847000')], dtype=object), array([Timestamp('1975-05-24 19:28:10.081000'),
#        Timestamp('1975-05-24 19:59:33.537000')], dtype=object), array([Timestamp('1975-05-24 19:38:41.749000'),
#        Timestamp('1975-05-24 20:17:01.839000')], dtype=object), array([Timestamp('1975-05-26 00:16:43.453000'),
#        Timestamp('1975-05-26 01:06:23.320000')], dtype=object), array([Timestamp('1975-05-26 01:46:04.142000'),
#        Timestamp('1975-05-26 01:58:00.294000')], dtype=object), array([Timestamp('1975-05-26 03:15:22.906000'),
#        Timestamp('1975-05-26 03:34:31.066000')], dtype=object), array([Timestamp('1975-05-26 03:35:07.562000'),
#        Timestamp('1975-05-26 03:54:13.797000')], dtype=object), array([Timestamp('1975-05-26 03:42:00.360000'),
#        Timestamp('1975-05-26 11:51:59.668000')], dtype=object), array([Timestamp('1975-05-26 03:52:32.051000'),
#        Timestamp('1975-05-26 12:07:07.842000')], dtype=object), array([Timestamp('1975-05-27 14:44:01.446000'),
#        Timestamp('1975-05-27 15:11:40.311000')], dtype=object), array([Timestamp('1975-05-27 16:46:54.145000'),
#        Timestamp('1975-05-27 18:16:53.328000')], dtype=object), array([Timestamp('1975-05-27 18:20:36.061000'),
#        Timestamp('1975-05-27 19:05:33.558000')], dtype=object), array([Timestamp('1975-05-27 20:27:59.317000'),
#        Timestamp('1975-05-27 21:28:10.715000')], dtype=object), array([Timestamp('1975-05-28 17:43:42.433000'),
#        Timestamp('1975-05-28 18:07:46.265000')], dtype=object), array([Timestamp('1975-05-28 19:01:31.848000'),
#        Timestamp('1975-05-28 19:41:35.656000')], dtype=object), array([Timestamp('1975-05-28 19:24:28.466000'),
#        Timestamp('1975-05-28 19:59:03.980000')], dtype=object), array([Timestamp('1975-05-28 19:34:54.373000'),
#        Timestamp('1975-05-28 20:08:13.088000')], dtype=object), array([Timestamp('1975-05-28 19:46:37.119000'),
#        Timestamp('1975-05-28 20:23:21.248000')], dtype=object), array([Timestamp('1975-05-28 20:55:03.953000'),
#        Timestamp('1975-05-28 21:42:14.028000')], dtype=object), array([Timestamp('1975-05-29 16:55:04.928000'),
#        Timestamp('1975-05-29 18:07:10.577000')], dtype=object), array([Timestamp('1975-05-29 17:48:33.172000'),
#        Timestamp('1975-05-29 18:35:02.855000')], dtype=object), array([Timestamp('1975-05-29 17:54:41.803000'),
#        Timestamp('1975-05-29 18:41:59.490000')], dtype=object), array([Timestamp('1975-05-29 20:04:23.376000'),
#        Timestamp('1975-05-29 21:02:18.509000')], dtype=object), array([Timestamp('1975-05-29 20:23:56.485000'),
#        Timestamp('1975-05-29 21:54:35.115000')], dtype=object), array([Timestamp('1975-05-30 17:42:20.063000'),
#        Timestamp('1975-05-30 18:07:19.550000')], dtype=object), array([Timestamp('1975-05-31 18:02:49.119000'),
#        Timestamp('1975-05-31 21:52:05.725000')], dtype=object), array([Timestamp('1975-05-31 18:41:13.063000'),
#        Timestamp('1975-05-31 22:14:12.443000')], dtype=object), array([Timestamp('1975-05-31 21:31:40.791000'),
#        Timestamp('1975-05-31 22:49:01.375000')], dtype=object), array([Timestamp('1975-06-01 01:00:34.388000'),
#        Timestamp('1975-06-01 05:14:10.248000')], dtype=object), array([Timestamp('1975-06-01 05:14:48.667000'),
#        Timestamp('1975-06-01 16:10:27.119000')], dtype=object), array([Timestamp('1975-06-01 21:05:46.692000'),
#        Timestamp('1975-06-01 21:21:02.512000')], dtype=object), array([Timestamp('1975-06-02 20:34:31.700000'),
#        Timestamp('1975-06-02 21:00:17.263000')], dtype=object), array([Timestamp('1975-06-03 01:06:58.265000'),
#        Timestamp('1975-06-03 01:36:16.951000')], dtype=object), array([Timestamp('1975-06-03 02:30:23.661000'),
#        Timestamp('1975-06-03 02:52:51.480000')], dtype=object), array([Timestamp('1975-06-03 03:07:23.143000'),
#        Timestamp('1975-06-03 03:36:57.229000')], dtype=object), array([Timestamp('1975-06-03 03:22:33.226000'),
#        Timestamp('1975-06-03 15:39:34.350000')], dtype=object), array([Timestamp('1975-06-03 15:41:21.869000'),
#        Timestamp('1975-06-03 16:34:11.771000')], dtype=object), array([Timestamp('1975-06-04 09:29:59.272000'),
#        Timestamp('1975-06-04 18:27:03.296000')], dtype=object), array([Timestamp('1975-06-04 19:33:57.949000'),
#        Timestamp('1975-06-04 20:27:32.005000')], dtype=object), array([Timestamp('1975-06-05 04:55:37.612000'),
#        Timestamp('1975-06-05 05:08:35.217000')], dtype=object), array([Timestamp('1975-06-05 08:06:57.009000'),
#        Timestamp('1975-06-05 09:07:23.663000')], dtype=object), array([Timestamp('1975-06-06 22:07:39.701000'),
#        Timestamp('1975-06-06 23:08:37.306000')], dtype=object), array([Timestamp('1975-06-07 09:52:34.215000'),
#        Timestamp('1975-06-07 10:20:41.876000')], dtype=object), array([Timestamp('1975-06-07 10:23:48.120000'),
#        Timestamp('1975-06-07 10:57:56.759000')], dtype=object), array([Timestamp('1975-06-08 23:18:34.020000'),
#        Timestamp('1975-06-08 23:53:32.541000')], dtype=object), array([Timestamp('1975-06-09 00:00:00.386000'),
#        Timestamp('1975-06-09 00:18:55.088000')], dtype=object), array([Timestamp('1975-06-09 02:48:38.658000'),
#        Timestamp('1975-06-09 03:10:20.392000')], dtype=object), array([Timestamp('1975-06-09 02:54:33.858000'),
#        Timestamp('1975-06-09 03:27:46.785000')], dtype=object), array([Timestamp('1975-06-09 03:27:08.406000'),
#        Timestamp('1975-06-09 06:00:57.732000')], dtype=object), array([Timestamp('1975-06-09 06:53:39.930000'),
#        Timestamp('1975-06-09 07:37:14.950000')], dtype=object), array([Timestamp('1975-06-09 07:05:11.122000'),
#        Timestamp('1975-06-09 07:49:55.241000')], dtype=object), array([Timestamp('1975-06-10 11:18:32.027000'),
#        Timestamp('1975-06-10 17:05:01.455000')], dtype=object), array([Timestamp('1975-06-10 17:53:14.821000'),
#        Timestamp('1975-06-10 18:28:40.240000')], dtype=object), array([Timestamp('1975-06-10 18:23:36.895000'),
#        Timestamp('1975-06-10 18:41:28.227000')], dtype=object), array([Timestamp('1975-06-11 06:39:20.110000'),
#        Timestamp('1975-06-11 06:59:33.542000')], dtype=object), array([Timestamp('1975-06-11 06:52:02.330000'),
#        Timestamp('1975-06-11 07:09:59.448000')], dtype=object), array([Timestamp('1975-06-11 12:55:40.988000'),
#        Timestamp('1975-06-11 13:55:58.211000')], dtype=object), array([Timestamp('1975-06-12 00:46:02.619000'),
#        Timestamp('1975-06-12 02:12:15.035000')], dtype=object), array([Timestamp('1975-06-12 06:55:36.521000'),
#        Timestamp('1975-06-12 08:23:15.301000')], dtype=object), array([Timestamp('1975-06-12 10:25:29.585000'),
#        Timestamp('1975-06-12 14:59:29.923000')], dtype=object), array([Timestamp('1975-06-12 10:47:32.453000'),
#        Timestamp('1975-06-12 15:26:01.574000')], dtype=object), array([Timestamp('1975-06-12 14:44:48.636000'),
#        Timestamp('1975-06-12 16:23:01.087000')], dtype=object), array([Timestamp('1975-06-12 14:56:29.455000'),
#        Timestamp('1975-06-12 16:34:22.656000')], dtype=object), array([Timestamp('1975-06-12 16:03:45.248000'),
#        Timestamp('1975-06-12 16:34:47.641000')], dtype=object), array([Timestamp('1975-06-13 06:56:32.680000'),
#        Timestamp('1975-06-13 08:00:55.740000')], dtype=object), array([Timestamp('1975-06-13 12:33:20.705000'),
#        Timestamp('1975-06-13 13:31:19.725000')], dtype=object), array([Timestamp('1975-06-14 08:38:05.199000'),
#        Timestamp('1975-06-14 12:56:36.646000')], dtype=object), array([Timestamp('1975-06-14 08:53:01.807000'),
#        Timestamp('1975-06-14 13:11:35.170000')], dtype=object), array([Timestamp('1975-06-14 12:23:31.392000'),
#        Timestamp('1975-06-14 13:41:51.467000')], dtype=object), array([Timestamp('1975-06-14 12:32:42.417000'),
#        Timestamp('1975-06-14 13:59:12.078000')], dtype=object), array([Timestamp('1975-06-15 06:55:24.724000'),
#        Timestamp('1975-06-15 08:05:46.777000')], dtype=object), array([Timestamp('1975-06-15 08:54:02.068000'),
#        Timestamp('1975-06-15 10:30:36.555000')], dtype=object), array([Timestamp('1975-06-16 08:47:27.134000'),
#        Timestamp('1975-06-16 09:26:08.392000')], dtype=object), array([Timestamp('1975-06-16 12:35:42.507000'),
#        Timestamp('1975-06-16 13:34:04.587000')], dtype=object), array([Timestamp('1975-06-16 13:23:29.092000'),
#        Timestamp('1975-06-16 14:11:17.562000')], dtype=object), array([Timestamp('1975-06-16 13:28:05.572000'),
#        Timestamp('1975-06-16 13:48:53.542000')], dtype=object), array([Timestamp('1975-06-17 05:27:31.338000'),
#        Timestamp('1975-06-17 05:55:12.138000')], dtype=object), array([Timestamp('1975-06-17 08:36:19.288000'),
#        Timestamp('1975-06-17 10:01:39.930000')], dtype=object), array([Timestamp('1975-06-17 09:42:45.218000'),
#        Timestamp('1975-06-17 10:21:26.497000')], dtype=object), array([Timestamp('1975-06-17 10:06:49.054000'),
#        Timestamp('1975-06-17 10:41:03.439000')], dtype=object), array([Timestamp('1975-06-17 10:41:49.519000'),
#        Timestamp('1975-06-17 11:22:52.887000')], dtype=object), array([Timestamp('1975-06-17 12:05:47.586000'),
#        Timestamp('1975-06-17 16:01:24.211000')], dtype=object), array([Timestamp('1975-06-17 16:15:29.003000'),
#        Timestamp('1975-06-17 17:53:24.130000')], dtype=object), array([Timestamp('1975-06-17 16:24:38.108000'),
#        Timestamp('1975-06-17 18:07:19.337000')], dtype=object), array([Timestamp('1975-06-17 17:54:10.209000'),
#        Timestamp('1975-06-17 19:17:18.314000')], dtype=object), array([Timestamp('1975-06-18 11:25:13.944000'),
#        Timestamp('1975-06-18 12:07:30.246000')], dtype=object), array([Timestamp('1975-06-18 11:34:38.449000'),
#        Timestamp('1975-06-18 12:15:51.387000')], dtype=object), array([Timestamp('1975-06-18 14:34:32.581000'),
#        Timestamp('1975-06-18 15:23:57.034000')], dtype=object), array([Timestamp('1975-06-18 15:23:26.314000'),
#        Timestamp('1975-06-18 16:25:19.550000')], dtype=object), array([Timestamp('1975-06-19 12:32:26.978000'),
#        Timestamp('1975-06-19 14:13:30.328000')], dtype=object), array([Timestamp('1975-06-19 13:07:14.013000'),
#        Timestamp('1975-06-19 14:29:30.308000')], dtype=object), array([Timestamp('1975-06-19 14:25:55.268000'),
#        Timestamp('1975-06-19 16:52:25.038000')], dtype=object), array([Timestamp('1975-06-19 15:47:14.013000'),
#        Timestamp('1975-06-19 17:36:26.958000')], dtype=object), array([Timestamp('1975-06-19 16:45:38.018000'),
#        Timestamp('1975-06-19 17:34:20.228000')], dtype=object), array([Timestamp('1975-06-20 11:37:07.859000'),
#        Timestamp('1975-06-20 12:02:36.147000')], dtype=object), array([Timestamp('1975-06-20 11:56:42.870000'),
#        Timestamp('1975-06-20 12:15:27.991000')], dtype=object), array([Timestamp('1975-06-20 14:07:12.559000'),
#        Timestamp('1975-06-20 14:38:01.519000')], dtype=object), array([Timestamp('1975-06-20 14:15:29.850000'),
#        Timestamp('1975-06-20 14:55:27.916000')], dtype=object), array([Timestamp('1975-06-20 14:35:18.335000'),
#        Timestamp('1975-06-20 15:22:01.494000')], dtype=object), array([Timestamp('1975-06-21 12:24:59.378000'),
#        Timestamp('1975-06-21 13:05:56.962000')], dtype=object), array([Timestamp('1975-06-21 23:24:32.888000'),
#        Timestamp('1975-06-21 23:52:30.991000')], dtype=object), array([Timestamp('1975-06-21 23:31:25.687000'),
#        Timestamp('1975-06-21 23:59:21.865000')], dtype=object), array([Timestamp('1975-06-22 00:55:31.506000'),
#        Timestamp('1975-06-22 11:13:23.136000')], dtype=object), array([Timestamp('1975-06-22 11:20:58.204000'),
#        Timestamp('1975-06-22 12:02:14.994000')], dtype=object), array([Timestamp('1975-06-22 11:58:03.496000'),
#        Timestamp('1975-06-22 12:06:59.176000')], dtype=object), array([Timestamp('1975-06-22 12:02:41.904000'),
#        Timestamp('1975-06-22 12:16:42.860000')], dtype=object), array([Timestamp('1975-06-22 14:14:32.365000'),
#        Timestamp('1975-06-22 15:05:53.975000')], dtype=object), array([Timestamp('1975-06-23 19:37:10.364000'),
#        Timestamp('1975-06-23 19:59:05.577000')], dtype=object), array([Timestamp('1975-06-23 20:09:58.351000'),
#        Timestamp('1975-06-23 21:43:24.700000')], dtype=object), array([Timestamp('1975-06-24 15:02:51.207000'),
#        Timestamp('1975-06-24 15:41:32.480000')], dtype=object), array([Timestamp('1975-06-24 18:15:12.241000'),
#        Timestamp('1975-06-24 19:59:58.299000')], dtype=object), array([Timestamp('1975-06-25 16:41:39.040000'),
#        Timestamp('1975-06-25 17:28:50.993000')], dtype=object), array([Timestamp('1975-06-25 17:01:52.470000'),
#        Timestamp('1975-06-25 17:31:18.857000')], dtype=object), array([Timestamp('1975-06-25 17:18:48.148000'),
#        Timestamp('1975-06-25 17:48:45.254000')], dtype=object), array([Timestamp('1975-06-25 18:09:08.269000'),
#        Timestamp('1975-06-25 18:37:23.631000')], dtype=object), array([Timestamp('1975-06-25 18:24:14.502000'),
#        Timestamp('1975-06-25 18:54:46.178000')], dtype=object), array([Timestamp('1975-06-25 19:45:25.509000'),
#        Timestamp('1975-06-25 20:42:55.707000')], dtype=object), array([Timestamp('1975-06-25 22:00:24.016000'),
#        Timestamp('1975-06-25 22:41:21.596000')], dtype=object), array([Timestamp('1975-06-25 22:11:53.285000'),
#        Timestamp('1975-06-25 22:52:45.091000')], dtype=object), array([Timestamp('1975-06-26 11:29:16.705000'),
#        Timestamp('1975-06-26 11:38:37.320000')], dtype=object), array([Timestamp('1975-06-26 12:25:22.439000'),
#        Timestamp('1975-06-26 12:55:19.543000')], dtype=object), array([Timestamp('1975-06-27 14:59:54.709000'),
#        Timestamp('1975-06-27 15:57:19.199000')], dtype=object), array([Timestamp('1975-06-27 19:07:00.959000'),
#        Timestamp('1975-06-27 19:37:07.664000')], dtype=object)]

# %%
timestamps = [timestamp for burst in bursts for timestamp in burst]

# Extract year and month
year_month = [f"{ts.year}-{ts.month:02d}" for ts in timestamps]

# Count events per month
month_counts = Counter(year_month)

# Convert to a sorted DataFrame for plotting
df = pd.DataFrame(sorted(month_counts.items()), columns=["Month", "Count"])
df["Month"] = pd.to_datetime(df["Month"])

# Plot histogram
plt.figure(figsize=(10, 6))
plt.bar(df["Month"], df["Count"], width=20, align='center')
plt.gca().xaxis_date()
plt.xlabel("Month")
plt.ylabel("Number of Burst Events")
plt.title("Histogram of Burst Events by Month")
plt.grid()
plt.tight_layout()
plt.show()

# %%
df.head(20)
# Out:
#         Month  Count
# 0  1974-01-01    324
# 1  1974-02-01    306
# 2  1974-03-01     64
# 3  1974-05-01    460
# 4  1974-06-01    408
# 5  1974-07-01    308
# 6  1974-08-01    304
# 7  1974-09-01    576
# 8  1974-10-01    320
# 9  1974-11-01    444
# 10 1974-12-01    294
# 11 1975-01-01    342
# 12 1975-02-01    380
# 13 1975-03-01    554
# 14 1975-04-01    262
# 15 1975-05-01    250
# 16 1975-06-01    190

# %%
monthly_counts = earthOccult.groupby(pd.Grouper(freq='M')).size()

# %%
monthly_hours = monthly_counts*1.9/3600

# %%
timestamps = [timestamp for burst in bursts for timestamp in burst]
year_month = [f"{ts.year}-{ts.month:02d}" for ts in timestamps]
month_counts = Counter(year_month)

# Step 2: Convert month_counts into a DataFrame
df_counts = pd.DataFrame(sorted(month_counts.items()), columns=["Month", "Count"])
df_counts["Month"] = pd.to_datetime(df_counts["Month"])
df_counts["Month"] = df_counts["Month"] + pd.offsets.MonthEnd(0)  # Shift to month-end

# Step 3: Prepare monthly_counts as DataFrame (already at month-end)
monthly_counts_df = monthly_hours.reset_index()
monthly_counts_df.columns = ["Month", "Total"]

# Step 4: Merge dataframes on Month and fill missing Total values with 0
merged_df = pd.merge(df_counts, monthly_counts_df, on="Month", how="outer").fillna({"Total": 0, "Count": 0})

# Step 5: Calculate rate safely, avoiding division by zero
merged_df["Rate"] = merged_df.apply(lambda row: row["Count"] / row["Total"] if row["Total"] > 0 else 0, axis=1)

# Step 6: Plot the rate
plt.figure(figsize=(10, 6))
plt.bar(merged_df["Month"], merged_df["Rate"], width=20, align="center")
plt.gca().xaxis_date()
plt.xlabel("Month")
plt.ylabel("Rate of Burst Events Per Hour")
plt.title("Rate of Burst Events by Month")
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Step 1: Flatten burst timestamps and count occurrences per month
timestamps = [timestamp for burst in bursts for timestamp in burst]
year_month = [f"{ts.year}-{ts.month:02d}" for ts in timestamps]
month_counts = Counter(year_month)

# Step 2: Convert month_counts into a DataFrame
df_counts = pd.DataFrame(sorted(month_counts.items()), columns=["Month", "Count"])
df_counts["Month"] = pd.to_datetime(df_counts["Month"])
df_counts["Month"] = df_counts["Month"] + pd.offsets.MonthEnd(0)  # Shift to month-end

# Step 3: Prepare monthly_counts as DataFrame (already at month-end)
monthly_counts_df = monthly_hours.reset_index()
monthly_counts_df.columns = ["Month", "Total"]

# Step 4: Merge dataframes on Month and fill missing Total values with 0
merged_df = pd.merge(df_counts, monthly_counts_df, on="Month", how="outer").fillna({"Total": 0, "Count": 0})

# Step 5: Calculate rate safely, avoiding division by zero
merged_df["Rate"] = merged_df.apply(lambda row: row["Count"] / row["Total"] if row["Total"] > 0 else 0, axis=1)

# Step 6: Calculate error bars as sqrt of counts
merged_df["Error"] = merged_df["Count"].apply(lambda count: np.sqrt(count) if count > 0 else 0)
merged_df["Month"] = merged_df["Month"] - pd.tseries.offsets.DateOffset(months=1)
# Step 7: Plot the rate with error bars
plt.figure(figsize=(10, 6))
plt.bar(
    merged_df["Month"], 
    merged_df["Rate"], 
    width=20, 
    align="center", 
    label="Rate of Burst Events"
)
plt.errorbar(
    merged_df["Month"], 
    merged_df["Rate"], 
    yerr=merged_df["Error"] / merged_df["Total"],  # Propagate error in rate
    fmt="none", 
    ecolor="red", 
    capsize=3
)

# Finalize the plot
plt.gca().xaxis_date()
plt.xlabel("Month")
plt.ylabel("Rate of Burst Events Per Hour")
plt.title("Rate of Burst Events by Month")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
df_counts.head()
# Out:
#        Month  Count
# 0 1974-01-01    324
# 1 1974-02-01    306
# 2 1974-03-01     64
# 3 1974-05-01    460
# 4 1974-06-01    408

# %%
merged_df.head()
# Out:
#        Month  Count  Total  Rate
# 0 1974-01-01  324.0    0.0   0.0
# 1 1974-02-01  306.0    0.0   0.0
# 2 1974-03-01   64.0    0.0   0.0
# 3 1974-05-01  460.0    0.0   0.0
# 4 1974-06-01  408.0    0.0   0.0

# %%
first_date = earthOccult.index[0]
date_title = first_date.strftime("%d %B %Y")

# Plot with the overall title
# %matplotlib qt
fig, axes = plt.subplots(3, 3, figsize=(9, 5 * len(frequencies)), sharex=True)

# Call burst_detection_chunks to get the bursts for each frequency band
burst_results = burst_detection_chunks(earthOccult)

# Create a list of frequencies (you may already have this variable)
frequencies = np.sort(earthOccult['frequency_band'].unique())
fig.suptitle(f"Burst Detection Sample - {date_title}", fontsize=16)
# Plotting each frequency band's data and detected bursts
for ax, freq in zip(axes.flatten(), frequencies):
    subset = earthOccult[earthOccult['frequency_band'] == freq]
    x = subset['TimeSince']
    y = subset['rv1_coarse']
    
    # Sigma clipping to establish baseline
    mask = sigmaClip(y, 3)
    med = np.median(y[mask])
    std = np.std(y[mask])
    
    # Plot all points
    ax.scatter(x, y, label='Data', alpha=0.5)
    
    # Highlight points in all burst windows
    for burst in burst_results:
        start_time, end_time = burst  # Unpack burst start and end times
        if freq in subset['frequency_band'].values:
            # Convert time indices to match data index
            valid_x = subset[(subset.index >= start_time) & (subset.index <= end_time)]['TimeSince']
            valid_y = subset[(subset.index >= start_time) & (subset.index <= end_time)]['rv1_coarse']
            
            # Plot the burst window in red
            ax.scatter(valid_x, valid_y, color='red', label='Burst Window', alpha=0.7)
    
    # Add 10-sigma line for context
    ax.axhline(med + 10 * std, color='green', linestyle='--', label='10σ Threshold')
    ax.axhline(med, color='blue', linestyle='-', label='Median')
    
    # Set plot details
    ax.set_title(f'Frequency: {bandToFreq(freq)}MHz', fontsize=10)
    
    # Only add x-axis label to the bottom row of plots
    if ax.is_last_row():
        ax.set_xlabel('Time since start of period (s)', fontsize=8)
    
    # Always add y-axis label
    ax.set_ylabel('Upper V (Uncalibrated)', fontsize=8)
    
    ax.grid(True)

# Avoid duplicate labels in the legend
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))
fig.legend(unique.values(), unique.keys(), loc='upper right')
fig.subplots_adjust(top=0.92, hspace=0.4, wspace=0.4)
plt.show()

# %%
# %matplotlib qt
fig, axes = plt.subplots(3, 3, figsize=(12, 8), sharex=True, sharey=True)

# Get the combined windows from burst detection results
burst_results = burst_detection_chunks(earthOccult, window_time=10, consec_points=7, chunk_size='24h')

# Get unique frequencies
frequencies = earthOccult['frequency_band'].unique()

for ax, freq in zip(axes.flatten(), frequencies):
    # Subset the data for the current frequency
    subset = earthOccult[earthOccult['frequency_band'] == freq]
    x = subset.index  # Use datetime index directly
    y = subset['rv1_coarse']
    
    # Sigma clipping to establish baseline
    mask = sigmaClip(y, 3)
    med = np.median(y[mask])
    std = np.std(y[mask])
    
    # Plot all points
    ax.scatter(x, y, label='Data', alpha=0.5)
    
    # Highlight points in all burst windows
    for start_time, (window_start, window_end) in burst_results.items():
        if freq in subset['frequency_band'].unique():
            # Find the overlapping indices in the subset
            valid_subset = subset.loc[window_start:window_end]
            valid_x = valid_subset.index  # Use datetime indices
            valid_y = valid_subset['rv1_coarse']
            ax.scatter(valid_x, valid_y, color='red', label='Burst Window', alpha=0.7)
    
    # Add 3-sigma line for context
    ax.axhline(med + 10 * std, color='green', linestyle='--', label='10σ Threshold')
    ax.axhline(med, color='blue', linestyle='-', label='Median')
    
    # Set plot details
    ax.set_title(f'Frequency: {bandToFreq(freq)} MHz')
    ax.set_xlabel('Time')
    ax.set_ylabel('rv1_coarse')
    ax.grid(True)

# Avoid duplicate labels in the legend
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))
fig.legend(unique.values(), unique.keys(), loc='upper right')
plt.subplots_adjust(hspace=0.8, wspace=0.4)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-4a7828bf57f3> in <module>
#      23
#      24     # Highlight points in all burst windows
# ---> 25     for start_time, (window_start, window_end) in burst_results.items():
#      26         if freq in subset['frequency_band'].unique():
#      27             # Find the overlapping indices in the subset
#
# AttributeError: 'list' object has no attribute 'items'

# %%
len(combined_windows)
# Out:
# 1

# %%
print(combined_windows[0][0])
# Out:
# 86
